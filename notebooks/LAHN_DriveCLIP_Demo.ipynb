# %% [markdown]
# # LAHN-DriveCLIP Demo
# This notebook clones the repository because the reusable implementation is stored there.

# %%
# !git clone https://github.com/imaniraei/LAHN-DriveCLIP.git
# %cd LAHN-DriveCLIP
# !pip install -q -r requirements.txt
# !bash scripts/setup_gscorecam.sh

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
IMAGE = '/content/example.jpg'
CHECKPOINT = '/content/drive/MyDrive/lahn_driveclip/last.pt'
PROMPT = 'a green traffic light'
OUTPUT = 'outputs/demo.png'

# %%
# !python demo.py --image "$IMAGE" --prompt "$PROMPT" --checkpoint "$CHECKPOINT" --output "$OUTPUT"

# %%
from IPython.display import Image, display
display(Image(filename=OUTPUT))
